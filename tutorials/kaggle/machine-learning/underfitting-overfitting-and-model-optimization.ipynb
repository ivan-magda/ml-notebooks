# %% [markdown]
# *This tutorial is part of the series [Learn Machine Learning](https://www.kaggle.com/learn/machine-learning). At the end of this step, you will understand the concepts of underfitting and overfitting, and you will be able to apply these ideas to optimize your model accuracy.*
#
# # Experimenting With Different Models
#
# Now that you have a trustworthy way to measure model accuracy, you can experiment with alternative models and see which gives the best predictions.  But what alternatives do you have for models?
#
# You can see in scikit-learn's [documentation](http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html) that the decision tree model has many options (more than you'll want or need for a long time). The most important options determine the tree's depth.  Recall from [page 2](https://www.kaggle.com/dansbecker/first-data-science-scenario-page-2/) that a tree's depth is a measure of how many splits it makes before coming to a prediction.  This is a relatively shallow tree
#
# ![Depth 2 Tree](http://i.imgur.com/R3ywQsR.png)
#
# In practice, it's not uncommon for a tree to have 10 splits between the top level (all houses and a leaf).  As the tree gets deeper, the dataset gets sliced up into leaves with fewer houses.  If a tree only had 1 split, it divides the data into 2 groups. If each group is split again, we would get 4 groups of houses.  Splitting each of those again would create 8 groups.  If we keep doubling the number of groups by adding more splits at each level, we'll have \\(2^{10}\\) groups of houses by the time we get to the 10th level. That's 1024 leaves.
#
# When we divide the houses amongst many leaves, we also have fewer houses in each leaf.  Leaves with very few houses will make predictions that are quite close to those homes' actual values, but they may make very unreliable predictions for new data (because each prediction is based on only a few houses).
#
# This is a phenomenon called **overfitting**, where a model matches the training data almost perfectly, but does poorly in validation and other new data.  On the flip side, if we make our tree very shallow, it doesn't divide up the houses into very distinct groups.
#
# At an extreme, if a tree divides houses into only 2 or 4, each group still has a wide variety of houses. Resulting predictions may be far off for most houses, even in the training data (and it will be bad in validation too for the same reason). When a model fails to capture important distinctions and patterns in the data, so it performs poorly even in training data, that is called **underfitting**.
#
# Since we care about accuracy on new data, which we estimate from our validation data, we want to find the sweet spot between underfitting and overfitting.  Visually, we want the low point of the (red) validation curve in
#
# ![underfitting_overfitting](http://i.imgur.com/2q85n9s.png)
#
# # Example
# There are a few alternatives for controlling the tree depth, and many allow for some routes through the tree to have greater depth than other routes.  But the *max_leaf_nodes* argument provides a very sensible way to control overfitting vs underfitting.  The more leaves we allow the model to make, the more we move from the underfitting area in the above graph to the overfitting area.
#
# We can use a utility function to help compare MAE scores from different values for *max_leaf_nodes*:

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, predictors_train, predictors_val, targ_train, targ_val):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(predictors_train, targ_train)
    preds_val = model.predict(predictors_val)
    mae = mean_absolute_error(targ_val, preds_val)
    return(mae)

# %% [markdown]
# The data is loaded into **train_X**, **val_X**, **train_y** and **val_y** using the code you've already seen (and which you've already written).

# %%
# Data Loading Code Runs At This Point
import pandas as pd
    
# Load data
melbourne_file_path = './data/melbourne-housing-snapshot/melb_data.csv'
melbourne_data = pd.read_csv(melbourne_file_path) 
# Filter rows with missing values
filtered_melbourne_data = melbourne_data.dropna(axis=0)
# Choose target and predictors
y = filtered_melbourne_data.Price
melbourne_predictors = ['Rooms', 'Bathroom', 'Landsize', 'BuildingArea', 
                        'YearBuilt', 'Lattitude', 'Longtitude']
X = filtered_melbourne_data[melbourne_predictors]

from sklearn.model_selection import train_test_split

# split data into training and validation data, for both predictors and target
train_X, val_X, train_y, val_y = train_test_split(X, y,random_state = 0)

# %% [markdown]
# We can use a for-loop to compare the accuracy of models built with different values for *max_leaf_nodes.*

# %%
# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  347380
# Max leaf nodes: 50  		 Mean Absolute Error:  257829
# Max leaf nodes: 500  		 Mean Absolute Error:  243176
# Max leaf nodes: 5000  		 Mean Absolute Error:  254915

# %% [markdown]
# Of the options listed, 500 is the optimal number of leaves.  Apply the function to your Iowa data to find the best decision tree.
# ---
#
# # Conclusion
#
# Here's the takeaway: Models can suffer from either:
# - **Overfitting:** capturing spurious patterns that won't recur in the future, leading to less accurate predictions, or
# - **Underfitting:** failing to capture relevant patterns, again leading to less accurate predictions.
#
# We use **validation** data, which isn't used in model training, to measure a candidate model's accuracy. This lets us try many candidate models and keep the best one.
#
# But we're still using Decision Tree models, which are not very sophisticated by modern machine learning standards.
#
# ---
# # Your Turn
# In the near future, you'll be efficient writing functions like `get_mae` yourself.  For now, just copy it over to your work area.  Then use a for loop that tries different values of *max_leaf_nodes* and calls the *get_mae* function on each to find the ideal number of leaves for your Iowa data.
#
# You should see that the ideal number of leaves for Iowa data is less than the ideal number of leaves for the Melbourne data. Remember, that a lower MAE is better.
#
# ---
#
# # Continue
# **[Click here](https://www.kaggle.com/dansbecker/random-forests)** to learn your first sophisticated Machine Learning model, the Random Forest. It is a clever extrapolation of the decision tree model that consistently leads to more accurate predictions.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

data = pd.read_csv('./data/house-prices-advanced-regression-techniques/train.csv')

X = data[["LotArea", "YearBuilt", "1stFlrSF", "2ndFlrSF", "FullBath", "BedroomAbvGr", "TotRmsAbvGrd"]]
y = data['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, X_train, X_test, y_train, y_test):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    
    return(mae)

# %%
import numpy as np

# %%
scores = []
for max_leaf_nodes in np.arange(5, 100000, 50):
    mae = get_mae(max_leaf_nodes, X_train, X_test, y_train, y_test)
    scores.append((max_leaf_nodes, mae))
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  35099
# Max leaf nodes: 55  		 Mean Absolute Error:  25041
# Max leaf nodes: 105  		 Mean Absolute Error:  26591
# Max leaf nodes: 155  		 Mean Absolute Error:  25916
# Max leaf nodes: 205  		 Mean Absolute Error:  27558
# Max leaf nodes: 255  		 Mean Absolute Error:  28065
# Max leaf nodes: 305  		 Mean Absolute Error:  28438
# Max leaf nodes: 355  		 Mean Absolute Error:  28535
# Max leaf nodes: 405  		 Mean Absolute Error:  28733
# Max leaf nodes: 455  		 Mean Absolute Error:  28679
# Max leaf nodes: 505  		 Mean Absolute Error:  29088
# Max leaf nodes: 555  		 Mean Absolute Error:  29128
# Max leaf nodes: 605  		 Mean Absolute Error:  29186
# Max leaf nodes: 655  		 Mean Absolute Error:  29147
# Max leaf nodes: 705  		 Mean Absolute Error:  29140
# Max leaf nodes: 755  		 Mean Absolute Error:  29103
# Max leaf nodes: 805  		 Mean Absolute Error:  29123
# Max leaf nodes: 855  		 Mean Absolute Error:  29142
# Max leaf nodes: 905  		 Mean Absolute Error:  29114
# Max leaf nodes: 955  		 Mean Absolute Error:  29121
# Max leaf nodes: 1005  		 Mean Absolute Error:  29130
# Max leaf nodes: 1055  		 Mean Absolute Error:  29130
# Max leaf nodes: 1105  		 Mean Absolute Error:  29130
# Max leaf nodes: 1155  		 Mean Absolute Error:  29130
# Max leaf nodes: 1205  		 Mean Absolute Error:  29130
# Max leaf nodes: 1255  		 Mean Absolute Error:  29130
# Max leaf nodes: 1305  		 Mean Absolute Error:  29130
# Max leaf nodes: 1355  		 Mean Absolute Error:  29130
# Max leaf nodes: 1405  		 Mean Absolute Error:  29130
# Max leaf nodes: 1455  		 Mean Absolute Error:  29130
# Max leaf nodes: 1505  		 Mean Absolute Error:  29130
# Max leaf nodes: 1555  		 Mean Absolute Error:  29130
# Max leaf nodes: 1605  		 Mean Absolute Error:  29130
# Max leaf nodes: 1655  		 Mean Absolute Error:  29130
# Max leaf nodes: 1705  		 Mean Absolute Error:  29130
# Max leaf nodes: 1755  		 Mean Absolute Error:  29130
# Max leaf nodes: 1805  		 Mean Absolute Error:  29130
# Max leaf nodes: 1855  		 Mean Absolute Error:  29130
# Max leaf nodes: 1905  		 Mean Absolute Error:  29130
# Max leaf nodes: 1955  		 Mean Absolute Error:  29130
# Max leaf nodes: 2005  		 Mean Absolute Error:  29130
# Max leaf nodes: 2055  		 Mean Absolute Error:  29130
# Max leaf nodes: 2105  		 Mean Absolute Error:  29130
# Max leaf nodes: 2155  		 Mean Absolute Error:  29130
# Max leaf nodes: 2205  		 Mean Absolute Error:  29130
# Max leaf nodes: 2255  		 Mean Absolute Error:  29130
# Max leaf nodes: 2305  		 Mean Absolute Error:  29130
# Max leaf nodes: 2355  		 Mean Absolute Error:  29130
# Max leaf nodes: 2405  		 Mean Absolute Error:  29130
# Max leaf nodes: 2455  		 Mean Absolute Error:  29130
# Max leaf nodes: 2505  		 Mean Absolute Error:  29130
# Max leaf nodes: 2555  		 Mean Absolute Error:  29130
# Max leaf nodes: 2605  		 Mean Absolute Error:  29130
# Max leaf nodes: 2655  		 Mean Absolute Error:  29130
# Max leaf nodes: 2705  		 Mean Absolute Error:  29130
# Max leaf nodes: 2755  		 Mean Absolute Error:  29130
# Max leaf nodes: 2805  		 Mean Absolute Error:  29130
# Max leaf nodes: 2855  		 Mean Absolute Error:  29130
# Max leaf nodes: 2905  		 Mean Absolute Error:  29130
# Max leaf nodes: 2955  		 Mean Absolute Error:  29130
# Max leaf nodes: 3005  		 Mean Absolute Error:  29130
# Max leaf nodes: 3055  		 Mean Absolute Error:  29130
# Max leaf nodes: 3105  		 Mean Absolute Error:  29130
# Max leaf nodes: 3155  		 Mean Absolute Error:  29130
# Max leaf nodes: 3205  		 Mean Absolute Error:  29130
# Max leaf nodes: 3255  		 Mean Absolute Error:  29130
# Max leaf nodes: 3305  		 Mean Absolute Error:  29130
# Max leaf nodes: 3355  		 Mean Absolute Error:  29130
# Max leaf nodes: 3405  		 Mean Absolute Error:  29130
# Max leaf nodes: 3455  		 Mean Absolute Error:  29130
# Max leaf nodes: 3505  		 Mean Absolute Error:  29130
# Max leaf nodes: 3555  		 Mean Absolute Error:  29130
# Max leaf nodes: 3605  		 Mean Absolute Error:  29130
# Max leaf nodes: 3655  		 Mean Absolute Error:  29130
# Max leaf nodes: 3705  		 Mean Absolute Error:  29130
# Max leaf nodes: 3755  		 Mean Absolute Error:  29130
# Max leaf nodes: 3805  		 Mean Absolute Error:  29130
# Max leaf nodes: 3855  		 Mean Absolute Error:  29130
# Max leaf nodes: 3905  		 Mean Absolute Error:  29130
# Max leaf nodes: 3955  		 Mean Absolute Error:  29130
# Max leaf nodes: 4005  		 Mean Absolute Error:  29130
# Max leaf nodes: 4055  		 Mean Absolute Error:  29130
# Max leaf nodes: 4105  		 Mean Absolute Error:  29130
# Max leaf nodes: 4155  		 Mean Absolute Error:  29130
# Max leaf nodes: 4205  		 Mean Absolute Error:  29130
# Max leaf nodes: 4255  		 Mean Absolute Error:  29130
# Max leaf nodes: 4305  		 Mean Absolute Error:  29130
# Max leaf nodes: 4355  		 Mean Absolute Error:  29130
# Max leaf nodes: 4405  		 Mean Absolute Error:  29130
# Max leaf nodes: 4455  		 Mean Absolute Error:  29130
# Max leaf nodes: 4505  		 Mean Absolute Error:  29130
# Max leaf nodes: 4555  		 Mean Absolute Error:  29130
# Max leaf nodes: 4605  		 Mean Absolute Error:  29130
# Max leaf nodes: 4655  		 Mean Absolute Error:  29130
# Max leaf nodes: 4705  		 Mean Absolute Error:  29130
# Max leaf nodes: 4755  		 Mean Absolute Error:  29130
# Max leaf nodes: 4805  		 Mean Absolute Error:  29130
# Max leaf nodes: 4855  		 Mean Absolute Error:  29130
# Max leaf nodes: 4905  		 Mean Absolute Error:  29130
# Max leaf nodes: 4955  		 Mean Absolute Error:  29130
# Max leaf nodes: 5005  		 Mean Absolute Error:  29130
# Max leaf nodes: 5055  		 Mean Absolute Error:  29130
# Max leaf nodes: 5105  		 Mean Absolute Error:  29130
# Max leaf nodes: 5155  		 Mean Absolute Error:  29130
# Max leaf nodes: 5205  		 Mean Absolute Error:  29130
# Max leaf nodes: 5255  		 Mean Absolute Error:  29130
# Max leaf nodes: 5305  		 Mean Absolute Error:  29130
# Max leaf nodes: 5355  		 Mean Absolute Error:  29130
# Max leaf nodes: 5405  		 Mean Absolute Error:  29130
# Max leaf nodes: 5455  		 Mean Absolute Error:  29130
# Max leaf nodes: 5505  		 Mean Absolute Error:  29130
# Max leaf nodes: 5555  		 Mean Absolute Error:  29130
# Max leaf nodes: 5605  		 Mean Absolute Error:  29130
# Max leaf nodes: 5655  		 Mean Absolute Error:  29130
# Max leaf nodes: 5705  		 Mean Absolute Error:  29130
# Max leaf nodes: 5755  		 Mean Absolute Error:  29130
# Max leaf nodes: 5805  		 Mean Absolute Error:  29130
# Max leaf nodes: 5855  		 Mean Absolute Error:  29130
# Max leaf nodes: 5905  		 Mean Absolute Error:  29130
# Max leaf nodes: 5955  		 Mean Absolute Error:  29130
# Max leaf nodes: 6005  		 Mean Absolute Error:  29130
# Max leaf nodes: 6055  		 Mean Absolute Error:  29130
# Max leaf nodes: 6105  		 Mean Absolute Error:  29130
# Max leaf nodes: 6155  		 Mean Absolute Error:  29130
# Max leaf nodes: 6205  		 Mean Absolute Error:  29130
# Max leaf nodes: 6255  		 Mean Absolute Error:  29130
# Max leaf nodes: 6305  		 Mean Absolute Error:  29130
# Max leaf nodes: 6355  		 Mean Absolute Error:  29130
# Max leaf nodes: 6405  		 Mean Absolute Error:  29130
# Max leaf nodes: 6455  		 Mean Absolute Error:  29130
# Max leaf nodes: 6505  		 Mean Absolute Error:  29130
# Max leaf nodes: 6555  		 Mean Absolute Error:  29130
# Max leaf nodes: 6605  		 Mean Absolute Error:  29130
# Max leaf nodes: 6655  		 Mean Absolute Error:  29130
# Max leaf nodes: 6705  		 Mean Absolute Error:  29130
# Max leaf nodes: 6755  		 Mean Absolute Error:  29130
# Max leaf nodes: 6805  		 Mean Absolute Error:  29130
# Max leaf nodes: 6855  		 Mean Absolute Error:  29130
# Max leaf nodes: 6905  		 Mean Absolute Error:  29130
# Max leaf nodes: 6955  		 Mean Absolute Error:  29130
# Max leaf nodes: 7005  		 Mean Absolute Error:  29130
# Max leaf nodes: 7055  		 Mean Absolute Error:  29130
# Max leaf nodes: 7105  		 Mean Absolute Error:  29130
# Max leaf nodes: 7155  		 Mean Absolute Error:  29130
# Max leaf nodes: 7205  		 Mean Absolute Error:  29130
# Max leaf nodes: 7255  		 Mean Absolute Error:  29130
# Max leaf nodes: 7305  		 Mean Absolute Error:  29130
# Max leaf nodes: 7355  		 Mean Absolute Error:  29130
# Max leaf nodes: 7405  		 Mean Absolute Error:  29130
# Max leaf nodes: 7455  		 Mean Absolute Error:  29130
# Max leaf nodes: 7505  		 Mean Absolute Error:  29130
# Max leaf nodes: 7555  		 Mean Absolute Error:  29130
# Max leaf nodes: 7605  		 Mean Absolute Error:  29130
# Max leaf nodes: 7655  		 Mean Absolute Error:  29130
# Max leaf nodes: 7705  		 Mean Absolute Error:  29130
# Max leaf nodes: 7755  		 Mean Absolute Error:  29130
# Max leaf nodes: 7805  		 Mean Absolute Error:  29130
# Max leaf nodes: 7855  		 Mean Absolute Error:  29130
# Max leaf nodes: 7905  		 Mean Absolute Error:  29130
# Max leaf nodes: 7955  		 Mean Absolute Error:  29130
# Max leaf nodes: 8005  		 Mean Absolute Error:  29130
# Max leaf nodes: 8055  		 Mean Absolute Error:  29130
# Max leaf nodes: 8105  		 Mean Absolute Error:  29130
# Max leaf nodes: 8155  		 Mean Absolute Error:  29130
# Max leaf nodes: 8205  		 Mean Absolute Error:  29130
# Max leaf nodes: 8255  		 Mean Absolute Error:  29130
# Max leaf nodes: 8305  		 Mean Absolute Error:  29130
# Max leaf nodes: 8355  		 Mean Absolute Error:  29130
# Max leaf nodes: 8405  		 Mean Absolute Error:  29130
# Max leaf nodes: 8455  		 Mean Absolute Error:  29130
# Max leaf nodes: 8505  		 Mean Absolute Error:  29130
# Max leaf nodes: 8555  		 Mean Absolute Error:  29130
# Max leaf nodes: 8605  		 Mean Absolute Error:  29130
# Max leaf nodes: 8655  		 Mean Absolute Error:  29130
# Max leaf nodes: 8705  		 Mean Absolute Error:  29130
# Max leaf nodes: 8755  		 Mean Absolute Error:  29130
# Max leaf nodes: 8805  		 Mean Absolute Error:  29130
# Max leaf nodes: 8855  		 Mean Absolute Error:  29130
# Max leaf nodes: 8905  		 Mean Absolute Error:  29130
# Max leaf nodes: 8955  		 Mean Absolute Error:  29130
# Max leaf nodes: 9005  		 Mean Absolute Error:  29130
# Max leaf nodes: 9055  		 Mean Absolute Error:  29130
# Max leaf nodes: 9105  		 Mean Absolute Error:  29130
# Max leaf nodes: 9155  		 Mean Absolute Error:  29130
# Max leaf nodes: 9205  		 Mean Absolute Error:  29130
# Max leaf nodes: 9255  		 Mean Absolute Error:  29130
# Max leaf nodes: 9305  		 Mean Absolute Error:  29130
# Max leaf nodes: 9355  		 Mean Absolute Error:  29130
# Max leaf nodes: 9405  		 Mean Absolute Error:  29130
# Max leaf nodes: 9455  		 Mean Absolute Error:  29130
# Max leaf nodes: 9505  		 Mean Absolute Error:  29130
# Max leaf nodes: 9555  		 Mean Absolute Error:  29130
# Max leaf nodes: 9605  		 Mean Absolute Error:  29130
# Max leaf nodes: 9655  		 Mean Absolute Error:  29130
# Max leaf nodes: 9705  		 Mean Absolute Error:  29130
# Max leaf nodes: 9755  		 Mean Absolute Error:  29130
# Max leaf nodes: 9805  		 Mean Absolute Error:  29130
# Max leaf nodes: 9855  		 Mean Absolute Error:  29130
# Max leaf nodes: 9905  		 Mean Absolute Error:  29130
# Max leaf nodes: 9955  		 Mean Absolute Error:  29130
# Max leaf nodes: 10005  		 Mean Absolute Error:  29130
# Max leaf nodes: 10055  		 Mean Absolute Error:  29130
# Max leaf nodes: 10105  		 Mean Absolute Error:  29130
# Max leaf nodes: 10155  		 Mean Absolute Error:  29130
# Max leaf nodes: 10205  		 Mean Absolute Error:  29130
# Max leaf nodes: 10255  		 Mean Absolute Error:  29130
# Max leaf nodes: 10305  		 Mean Absolute Error:  29130
# Max leaf nodes: 10355  		 Mean Absolute Error:  29130
# Max leaf nodes: 10405  		 Mean Absolute Error:  29130
# Max leaf nodes: 10455  		 Mean Absolute Error:  29130
# Max leaf nodes: 10505  		 Mean Absolute Error:  29130
# Max leaf nodes: 10555  		 Mean Absolute Error:  29130
# Max leaf nodes: 10605  		 Mean Absolute Error:  29130
# Max leaf nodes: 10655  		 Mean Absolute Error:  29130
# Max leaf nodes: 10705  		 Mean Absolute Error:  29130
# Max leaf nodes: 10755  		 Mean Absolute Error:  29130
# Max leaf nodes: 10805  		 Mean Absolute Error:  29130
# Max leaf nodes: 10855  		 Mean Absolute Error:  29130
# Max leaf nodes: 10905  		 Mean Absolute Error:  29130
# Max leaf nodes: 10955  		 Mean Absolute Error:  29130
# Max leaf nodes: 11005  		 Mean Absolute Error:  29130
# Max leaf nodes: 11055  		 Mean Absolute Error:  29130
# Max leaf nodes: 11105  		 Mean Absolute Error:  29130
# Max leaf nodes: 11155  		 Mean Absolute Error:  29130
# Max leaf nodes: 11205  		 Mean Absolute Error:  29130
# Max leaf nodes: 11255  		 Mean Absolute Error:  29130
# Max leaf nodes: 11305  		 Mean Absolute Error:  29130
# Max leaf nodes: 11355  		 Mean Absolute Error:  29130
# Max leaf nodes: 11405  		 Mean Absolute Error:  29130
# Max leaf nodes: 11455  		 Mean Absolute Error:  29130
# Max leaf nodes: 11505  		 Mean Absolute Error:  29130
# Max leaf nodes: 11555  		 Mean Absolute Error:  29130
# Max leaf nodes: 11605  		 Mean Absolute Error:  29130
# Max leaf nodes: 11655  		 Mean Absolute Error:  29130
# Max leaf nodes: 11705  		 Mean Absolute Error:  29130
# Max leaf nodes: 11755  		 Mean Absolute Error:  29130
# Max leaf nodes: 11805  		 Mean Absolute Error:  29130
# Max leaf nodes: 11855  		 Mean Absolute Error:  29130
# Max leaf nodes: 11905  		 Mean Absolute Error:  29130
# Max leaf nodes: 11955  		 Mean Absolute Error:  29130
# Max leaf nodes: 12005  		 Mean Absolute Error:  29130
# Max leaf nodes: 12055  		 Mean Absolute Error:  29130
# Max leaf nodes: 12105  		 Mean Absolute Error:  29130
# Max leaf nodes: 12155  		 Mean Absolute Error:  29130
# Max leaf nodes: 12205  		 Mean Absolute Error:  29130
# Max leaf nodes: 12255  		 Mean Absolute Error:  29130
# Max leaf nodes: 12305  		 Mean Absolute Error:  29130
# Max leaf nodes: 12355  		 Mean Absolute Error:  29130
# Max leaf nodes: 12405  		 Mean Absolute Error:  29130
# Max leaf nodes: 12455  		 Mean Absolute Error:  29130
# Max leaf nodes: 12505  		 Mean Absolute Error:  29130
# Max leaf nodes: 12555  		 Mean Absolute Error:  29130
# Max leaf nodes: 12605  		 Mean Absolute Error:  29130
# Max leaf nodes: 12655  		 Mean Absolute Error:  29130
# Max leaf nodes: 12705  		 Mean Absolute Error:  29130
# Max leaf nodes: 12755  		 Mean Absolute Error:  29130
# Max leaf nodes: 12805  		 Mean Absolute Error:  29130
# Max leaf nodes: 12855  		 Mean Absolute Error:  29130
# Max leaf nodes: 12905  		 Mean Absolute Error:  29130
# Max leaf nodes: 12955  		 Mean Absolute Error:  29130
# Max leaf nodes: 13005  		 Mean Absolute Error:  29130
# Max leaf nodes: 13055  		 Mean Absolute Error:  29130
# Max leaf nodes: 13105  		 Mean Absolute Error:  29130
# Max leaf nodes: 13155  		 Mean Absolute Error:  29130
# Max leaf nodes: 13205  		 Mean Absolute Error:  29130
# Max leaf nodes: 13255  		 Mean Absolute Error:  29130
# Max leaf nodes: 13305  		 Mean Absolute Error:  29130
# Max leaf nodes: 13355  		 Mean Absolute Error:  29130
# Max leaf nodes: 13405  		 Mean Absolute Error:  29130
# Max leaf nodes: 13455  		 Mean Absolute Error:  29130
# Max leaf nodes: 13505  		 Mean Absolute Error:  29130
# Max leaf nodes: 13555  		 Mean Absolute Error:  29130
# Max leaf nodes: 13605  		 Mean Absolute Error:  29130
# Max leaf nodes: 13655  		 Mean Absolute Error:  29130
# Max leaf nodes: 13705  		 Mean Absolute Error:  29130
# Max leaf nodes: 13755  		 Mean Absolute Error:  29130
# Max leaf nodes: 13805  		 Mean Absolute Error:  29130
# Max leaf nodes: 13855  		 Mean Absolute Error:  29130
# Max leaf nodes: 13905  		 Mean Absolute Error:  29130
# Max leaf nodes: 13955  		 Mean Absolute Error:  29130
# Max leaf nodes: 14005  		 Mean Absolute Error:  29130
# Max leaf nodes: 14055  		 Mean Absolute Error:  29130
# Max leaf nodes: 14105  		 Mean Absolute Error:  29130
# Max leaf nodes: 14155  		 Mean Absolute Error:  29130
# Max leaf nodes: 14205  		 Mean Absolute Error:  29130
# Max leaf nodes: 14255  		 Mean Absolute Error:  29130
# Max leaf nodes: 14305  		 Mean Absolute Error:  29130
# Max leaf nodes: 14355  		 Mean Absolute Error:  29130
# Max leaf nodes: 14405  		 Mean Absolute Error:  29130
# Max leaf nodes: 14455  		 Mean Absolute Error:  29130
# Max leaf nodes: 14505  		 Mean Absolute Error:  29130
# Max leaf nodes: 14555  		 Mean Absolute Error:  29130
# Max leaf nodes: 14605  		 Mean Absolute Error:  29130
# Max leaf nodes: 14655  		 Mean Absolute Error:  29130
# Max leaf nodes: 14705  		 Mean Absolute Error:  29130
# Max leaf nodes: 14755  		 Mean Absolute Error:  29130
# Max leaf nodes: 14805  		 Mean Absolute Error:  29130
# Max leaf nodes: 14855  		 Mean Absolute Error:  29130
# Max leaf nodes: 14905  		 Mean Absolute Error:  29130
# Max leaf nodes: 14955  		 Mean Absolute Error:  29130
# Max leaf nodes: 15005  		 Mean Absolute Error:  29130
# Max leaf nodes: 15055  		 Mean Absolute Error:  29130
# Max leaf nodes: 15105  		 Mean Absolute Error:  29130
# Max leaf nodes: 15155  		 Mean Absolute Error:  29130
# Max leaf nodes: 15205  		 Mean Absolute Error:  29130
# Max leaf nodes: 15255  		 Mean Absolute Error:  29130
# Max leaf nodes: 15305  		 Mean Absolute Error:  29130
# Max leaf nodes: 15355  		 Mean Absolute Error:  29130
# Max leaf nodes: 15405  		 Mean Absolute Error:  29130
# Max leaf nodes: 15455  		 Mean Absolute Error:  29130
# Max leaf nodes: 15505  		 Mean Absolute Error:  29130
# Max leaf nodes: 15555  		 Mean Absolute Error:  29130
# Max leaf nodes: 15605  		 Mean Absolute Error:  29130
# Max leaf nodes: 15655  		 Mean Absolute Error:  29130
# Max leaf nodes: 15705  		 Mean Absolute Error:  29130
# Max leaf nodes: 15755  		 Mean Absolute Error:  29130
# Max leaf nodes: 15805  		 Mean Absolute Error:  29130
# Max leaf nodes: 15855  		 Mean Absolute Error:  29130
# Max leaf nodes: 15905  		 Mean Absolute Error:  29130
# Max leaf nodes: 15955  		 Mean Absolute Error:  29130
# Max leaf nodes: 16005  		 Mean Absolute Error:  29130
# Max leaf nodes: 16055  		 Mean Absolute Error:  29130
# Max leaf nodes: 16105  		 Mean Absolute Error:  29130
# Max leaf nodes: 16155  		 Mean Absolute Error:  29130
# Max leaf nodes: 16205  		 Mean Absolute Error:  29130
# Max leaf nodes: 16255  		 Mean Absolute Error:  29130
# Max leaf nodes: 16305  		 Mean Absolute Error:  29130
# Max leaf nodes: 16355  		 Mean Absolute Error:  29130
# Max leaf nodes: 16405  		 Mean Absolute Error:  29130
# Max leaf nodes: 16455  		 Mean Absolute Error:  29130
# Max leaf nodes: 16505  		 Mean Absolute Error:  29130
# Max leaf nodes: 16555  		 Mean Absolute Error:  29130
# Max leaf nodes: 16605  		 Mean Absolute Error:  29130
# Max leaf nodes: 16655  		 Mean Absolute Error:  29130
# Max leaf nodes: 16705  		 Mean Absolute Error:  29130
# Max leaf nodes: 16755  		 Mean Absolute Error:  29130
# Max leaf nodes: 16805  		 Mean Absolute Error:  29130
# Max leaf nodes: 16855  		 Mean Absolute Error:  29130
# Max leaf nodes: 16905  		 Mean Absolute Error:  29130
# Max leaf nodes: 16955  		 Mean Absolute Error:  29130
# Max leaf nodes: 17005  		 Mean Absolute Error:  29130
# Max leaf nodes: 17055  		 Mean Absolute Error:  29130
# Max leaf nodes: 17105  		 Mean Absolute Error:  29130
# Max leaf nodes: 17155  		 Mean Absolute Error:  29130
# Max leaf nodes: 17205  		 Mean Absolute Error:  29130
# Max leaf nodes: 17255  		 Mean Absolute Error:  29130
# Max leaf nodes: 17305  		 Mean Absolute Error:  29130
# Max leaf nodes: 17355  		 Mean Absolute Error:  29130
# Max leaf nodes: 17405  		 Mean Absolute Error:  29130
# Max leaf nodes: 17455  		 Mean Absolute Error:  29130
# Max leaf nodes: 17505  		 Mean Absolute Error:  29130
# Max leaf nodes: 17555  		 Mean Absolute Error:  29130
# Max leaf nodes: 17605  		 Mean Absolute Error:  29130
# Max leaf nodes: 17655  		 Mean Absolute Error:  29130
# Max leaf nodes: 17705  		 Mean Absolute Error:  29130
# Max leaf nodes: 17755  		 Mean Absolute Error:  29130
# Max leaf nodes: 17805  		 Mean Absolute Error:  29130
# Max leaf nodes: 17855  		 Mean Absolute Error:  29130
# Max leaf nodes: 17905  		 Mean Absolute Error:  29130
# Max leaf nodes: 17955  		 Mean Absolute Error:  29130
# Max leaf nodes: 18005  		 Mean Absolute Error:  29130
# Max leaf nodes: 18055  		 Mean Absolute Error:  29130
# Max leaf nodes: 18105  		 Mean Absolute Error:  29130
# Max leaf nodes: 18155  		 Mean Absolute Error:  29130
# Max leaf nodes: 18205  		 Mean Absolute Error:  29130
# Max leaf nodes: 18255  		 Mean Absolute Error:  29130
# Max leaf nodes: 18305  		 Mean Absolute Error:  29130
# Max leaf nodes: 18355  		 Mean Absolute Error:  29130
# Max leaf nodes: 18405  		 Mean Absolute Error:  29130
# Max leaf nodes: 18455  		 Mean Absolute Error:  29130
# Max leaf nodes: 18505  		 Mean Absolute Error:  29130
# Max leaf nodes: 18555  		 Mean Absolute Error:  29130
# Max leaf nodes: 18605  		 Mean Absolute Error:  29130
# Max leaf nodes: 18655  		 Mean Absolute Error:  29130
# Max leaf nodes: 18705  		 Mean Absolute Error:  29130
# Max leaf nodes: 18755  		 Mean Absolute Error:  29130
# Max leaf nodes: 18805  		 Mean Absolute Error:  29130
# Max leaf nodes: 18855  		 Mean Absolute Error:  29130
# Max leaf nodes: 18905  		 Mean Absolute Error:  29130
# Max leaf nodes: 18955  		 Mean Absolute Error:  29130
# Max leaf nodes: 19005  		 Mean Absolute Error:  29130
# Max leaf nodes: 19055  		 Mean Absolute Error:  29130
# Max leaf nodes: 19105  		 Mean Absolute Error:  29130
# Max leaf nodes: 19155  		 Mean Absolute Error:  29130
# Max leaf nodes: 19205  		 Mean Absolute Error:  29130
# Max leaf nodes: 19255  		 Mean Absolute Error:  29130
# Max leaf nodes: 19305  		 Mean Absolute Error:  29130
# Max leaf nodes: 19355  		 Mean Absolute Error:  29130
# Max leaf nodes: 19405  		 Mean Absolute Error:  29130
# Max leaf nodes: 19455  		 Mean Absolute Error:  29130
# Max leaf nodes: 19505  		 Mean Absolute Error:  29130
# Max leaf nodes: 19555  		 Mean Absolute Error:  29130
# Max leaf nodes: 19605  		 Mean Absolute Error:  29130
# Max leaf nodes: 19655  		 Mean Absolute Error:  29130
# Max leaf nodes: 19705  		 Mean Absolute Error:  29130
# Max leaf nodes: 19755  		 Mean Absolute Error:  29130
# Max leaf nodes: 19805  		 Mean Absolute Error:  29130
# Max leaf nodes: 19855  		 Mean Absolute Error:  29130
# Max leaf nodes: 19905  		 Mean Absolute Error:  29130
# Max leaf nodes: 19955  		 Mean Absolute Error:  29130
# Max leaf nodes: 20005  		 Mean Absolute Error:  29130
# Max leaf nodes: 20055  		 Mean Absolute Error:  29130
# Max leaf nodes: 20105  		 Mean Absolute Error:  29130
# Max leaf nodes: 20155  		 Mean Absolute Error:  29130
# Max leaf nodes: 20205  		 Mean Absolute Error:  29130
# Max leaf nodes: 20255  		 Mean Absolute Error:  29130
# Max leaf nodes: 20305  		 Mean Absolute Error:  29130
# Max leaf nodes: 20355  		 Mean Absolute Error:  29130
# Max leaf nodes: 20405  		 Mean Absolute Error:  29130
# Max leaf nodes: 20455  		 Mean Absolute Error:  29130
# Max leaf nodes: 20505  		 Mean Absolute Error:  29130
# Max leaf nodes: 20555  		 Mean Absolute Error:  29130
# Max leaf nodes: 20605  		 Mean Absolute Error:  29130
# Max leaf nodes: 20655  		 Mean Absolute Error:  29130
# Max leaf nodes: 20705  		 Mean Absolute Error:  29130
# Max leaf nodes: 20755  		 Mean Absolute Error:  29130
# Max leaf nodes: 20805  		 Mean Absolute Error:  29130
# Max leaf nodes: 20855  		 Mean Absolute Error:  29130
# Max leaf nodes: 20905  		 Mean Absolute Error:  29130
# Max leaf nodes: 20955  		 Mean Absolute Error:  29130
# Max leaf nodes: 21005  		 Mean Absolute Error:  29130
# Max leaf nodes: 21055  		 Mean Absolute Error:  29130
# Max leaf nodes: 21105  		 Mean Absolute Error:  29130
# Max leaf nodes: 21155  		 Mean Absolute Error:  29130
# Max leaf nodes: 21205  		 Mean Absolute Error:  29130
# Max leaf nodes: 21255  		 Mean Absolute Error:  29130
# Max leaf nodes: 21305  		 Mean Absolute Error:  29130
# Max leaf nodes: 21355  		 Mean Absolute Error:  29130
# Max leaf nodes: 21405  		 Mean Absolute Error:  29130
# Max leaf nodes: 21455  		 Mean Absolute Error:  29130
# Max leaf nodes: 21505  		 Mean Absolute Error:  29130
# Max leaf nodes: 21555  		 Mean Absolute Error:  29130
# Max leaf nodes: 21605  		 Mean Absolute Error:  29130
# Max leaf nodes: 21655  		 Mean Absolute Error:  29130
# Max leaf nodes: 21705  		 Mean Absolute Error:  29130
# Max leaf nodes: 21755  		 Mean Absolute Error:  29130
# Max leaf nodes: 21805  		 Mean Absolute Error:  29130
# Max leaf nodes: 21855  		 Mean Absolute Error:  29130
# Max leaf nodes: 21905  		 Mean Absolute Error:  29130
# Max leaf nodes: 21955  		 Mean Absolute Error:  29130
# Max leaf nodes: 22005  		 Mean Absolute Error:  29130
# Max leaf nodes: 22055  		 Mean Absolute Error:  29130
# Max leaf nodes: 22105  		 Mean Absolute Error:  29130
# Max leaf nodes: 22155  		 Mean Absolute Error:  29130
# Max leaf nodes: 22205  		 Mean Absolute Error:  29130
# Max leaf nodes: 22255  		 Mean Absolute Error:  29130
# Max leaf nodes: 22305  		 Mean Absolute Error:  29130
# Max leaf nodes: 22355  		 Mean Absolute Error:  29130
# Max leaf nodes: 22405  		 Mean Absolute Error:  29130
# Max leaf nodes: 22455  		 Mean Absolute Error:  29130
# Max leaf nodes: 22505  		 Mean Absolute Error:  29130
# Max leaf nodes: 22555  		 Mean Absolute Error:  29130
# Max leaf nodes: 22605  		 Mean Absolute Error:  29130
# Max leaf nodes: 22655  		 Mean Absolute Error:  29130
# Max leaf nodes: 22705  		 Mean Absolute Error:  29130
# Max leaf nodes: 22755  		 Mean Absolute Error:  29130
# Max leaf nodes: 22805  		 Mean Absolute Error:  29130
# Max leaf nodes: 22855  		 Mean Absolute Error:  29130
# Max leaf nodes: 22905  		 Mean Absolute Error:  29130
# Max leaf nodes: 22955  		 Mean Absolute Error:  29130
# Max leaf nodes: 23005  		 Mean Absolute Error:  29130
# Max leaf nodes: 23055  		 Mean Absolute Error:  29130
# Max leaf nodes: 23105  		 Mean Absolute Error:  29130
# Max leaf nodes: 23155  		 Mean Absolute Error:  29130
# Max leaf nodes: 23205  		 Mean Absolute Error:  29130
# Max leaf nodes: 23255  		 Mean Absolute Error:  29130
# Max leaf nodes: 23305  		 Mean Absolute Error:  29130
# Max leaf nodes: 23355  		 Mean Absolute Error:  29130
# Max leaf nodes: 23405  		 Mean Absolute Error:  29130
# Max leaf nodes: 23455  		 Mean Absolute Error:  29130
# Max leaf nodes: 23505  		 Mean Absolute Error:  29130
# Max leaf nodes: 23555  		 Mean Absolute Error:  29130
# Max leaf nodes: 23605  		 Mean Absolute Error:  29130
# Max leaf nodes: 23655  		 Mean Absolute Error:  29130
# Max leaf nodes: 23705  		 Mean Absolute Error:  29130
# Max leaf nodes: 23755  		 Mean Absolute Error:  29130
# Max leaf nodes: 23805  		 Mean Absolute Error:  29130
# Max leaf nodes: 23855  		 Mean Absolute Error:  29130
# Max leaf nodes: 23905  		 Mean Absolute Error:  29130
# Max leaf nodes: 23955  		 Mean Absolute Error:  29130
# Max leaf nodes: 24005  		 Mean Absolute Error:  29130
# Max leaf nodes: 24055  		 Mean Absolute Error:  29130
# Max leaf nodes: 24105  		 Mean Absolute Error:  29130
# Max leaf nodes: 24155  		 Mean Absolute Error:  29130
# Max leaf nodes: 24205  		 Mean Absolute Error:  29130
# Max leaf nodes: 24255  		 Mean Absolute Error:  29130
# Max leaf nodes: 24305  		 Mean Absolute Error:  29130
# Max leaf nodes: 24355  		 Mean Absolute Error:  29130
# Max leaf nodes: 24405  		 Mean Absolute Error:  29130
# Max leaf nodes: 24455  		 Mean Absolute Error:  29130
# Max leaf nodes: 24505  		 Mean Absolute Error:  29130
# Max leaf nodes: 24555  		 Mean Absolute Error:  29130
# Max leaf nodes: 24605  		 Mean Absolute Error:  29130
# Max leaf nodes: 24655  		 Mean Absolute Error:  29130
# Max leaf nodes: 24705  		 Mean Absolute Error:  29130
# Max leaf nodes: 24755  		 Mean Absolute Error:  29130
# Max leaf nodes: 24805  		 Mean Absolute Error:  29130
# Max leaf nodes: 24855  		 Mean Absolute Error:  29130
# Max leaf nodes: 24905  		 Mean Absolute Error:  29130
# Max leaf nodes: 24955  		 Mean Absolute Error:  29130
# Max leaf nodes: 25005  		 Mean Absolute Error:  29130
# Max leaf nodes: 25055  		 Mean Absolute Error:  29130
# Max leaf nodes: 25105  		 Mean Absolute Error:  29130
# Max leaf nodes: 25155  		 Mean Absolute Error:  29130
# Max leaf nodes: 25205  		 Mean Absolute Error:  29130
# Max leaf nodes: 25255  		 Mean Absolute Error:  29130
# Max leaf nodes: 25305  		 Mean Absolute Error:  29130
# Max leaf nodes: 25355  		 Mean Absolute Error:  29130
# Max leaf nodes: 25405  		 Mean Absolute Error:  29130
# Max leaf nodes: 25455  		 Mean Absolute Error:  29130
# Max leaf nodes: 25505  		 Mean Absolute Error:  29130
# Max leaf nodes: 25555  		 Mean Absolute Error:  29130
# Max leaf nodes: 25605  		 Mean Absolute Error:  29130
# Max leaf nodes: 25655  		 Mean Absolute Error:  29130
# Max leaf nodes: 25705  		 Mean Absolute Error:  29130
# Max leaf nodes: 25755  		 Mean Absolute Error:  29130
# Max leaf nodes: 25805  		 Mean Absolute Error:  29130
# Max leaf nodes: 25855  		 Mean Absolute Error:  29130
# Max leaf nodes: 25905  		 Mean Absolute Error:  29130
# Max leaf nodes: 25955  		 Mean Absolute Error:  29130
# Max leaf nodes: 26005  		 Mean Absolute Error:  29130
# Max leaf nodes: 26055  		 Mean Absolute Error:  29130
# Max leaf nodes: 26105  		 Mean Absolute Error:  29130
# Max leaf nodes: 26155  		 Mean Absolute Error:  29130
# Max leaf nodes: 26205  		 Mean Absolute Error:  29130
# Max leaf nodes: 26255  		 Mean Absolute Error:  29130
# Max leaf nodes: 26305  		 Mean Absolute Error:  29130
# Max leaf nodes: 26355  		 Mean Absolute Error:  29130
# Max leaf nodes: 26405  		 Mean Absolute Error:  29130
# Max leaf nodes: 26455  		 Mean Absolute Error:  29130
# Max leaf nodes: 26505  		 Mean Absolute Error:  29130
# Max leaf nodes: 26555  		 Mean Absolute Error:  29130
# Max leaf nodes: 26605  		 Mean Absolute Error:  29130
# Max leaf nodes: 26655  		 Mean Absolute Error:  29130
# Max leaf nodes: 26705  		 Mean Absolute Error:  29130
# Max leaf nodes: 26755  		 Mean Absolute Error:  29130
# Max leaf nodes: 26805  		 Mean Absolute Error:  29130
# Max leaf nodes: 26855  		 Mean Absolute Error:  29130
# Max leaf nodes: 26905  		 Mean Absolute Error:  29130
# Max leaf nodes: 26955  		 Mean Absolute Error:  29130
# Max leaf nodes: 27005  		 Mean Absolute Error:  29130
# Max leaf nodes: 27055  		 Mean Absolute Error:  29130
# Max leaf nodes: 27105  		 Mean Absolute Error:  29130
# Max leaf nodes: 27155  		 Mean Absolute Error:  29130
# Max leaf nodes: 27205  		 Mean Absolute Error:  29130
# Max leaf nodes: 27255  		 Mean Absolute Error:  29130
# Max leaf nodes: 27305  		 Mean Absolute Error:  29130
# Max leaf nodes: 27355  		 Mean Absolute Error:  29130
# Max leaf nodes: 27405  		 Mean Absolute Error:  29130
# Max leaf nodes: 27455  		 Mean Absolute Error:  29130
# Max leaf nodes: 27505  		 Mean Absolute Error:  29130
# Max leaf nodes: 27555  		 Mean Absolute Error:  29130
# Max leaf nodes: 27605  		 Mean Absolute Error:  29130
# Max leaf nodes: 27655  		 Mean Absolute Error:  29130
# Max leaf nodes: 27705  		 Mean Absolute Error:  29130
# Max leaf nodes: 27755  		 Mean Absolute Error:  29130
# Max leaf nodes: 27805  		 Mean Absolute Error:  29130
# Max leaf nodes: 27855  		 Mean Absolute Error:  29130
# Max leaf nodes: 27905  		 Mean Absolute Error:  29130
# Max leaf nodes: 27955  		 Mean Absolute Error:  29130
# Max leaf nodes: 28005  		 Mean Absolute Error:  29130
# Max leaf nodes: 28055  		 Mean Absolute Error:  29130
# Max leaf nodes: 28105  		 Mean Absolute Error:  29130
# Max leaf nodes: 28155  		 Mean Absolute Error:  29130
# Max leaf nodes: 28205  		 Mean Absolute Error:  29130
# Max leaf nodes: 28255  		 Mean Absolute Error:  29130
# Max leaf nodes: 28305  		 Mean Absolute Error:  29130
# Max leaf nodes: 28355  		 Mean Absolute Error:  29130
# Max leaf nodes: 28405  		 Mean Absolute Error:  29130
# Max leaf nodes: 28455  		 Mean Absolute Error:  29130
# Max leaf nodes: 28505  		 Mean Absolute Error:  29130
# Max leaf nodes: 28555  		 Mean Absolute Error:  29130
# Max leaf nodes: 28605  		 Mean Absolute Error:  29130
# Max leaf nodes: 28655  		 Mean Absolute Error:  29130
# Max leaf nodes: 28705  		 Mean Absolute Error:  29130
# Max leaf nodes: 28755  		 Mean Absolute Error:  29130
# Max leaf nodes: 28805  		 Mean Absolute Error:  29130
# Max leaf nodes: 28855  		 Mean Absolute Error:  29130
# Max leaf nodes: 28905  		 Mean Absolute Error:  29130
# Max leaf nodes: 28955  		 Mean Absolute Error:  29130
# Max leaf nodes: 29005  		 Mean Absolute Error:  29130
# Max leaf nodes: 29055  		 Mean Absolute Error:  29130
# Max leaf nodes: 29105  		 Mean Absolute Error:  29130
# Max leaf nodes: 29155  		 Mean Absolute Error:  29130
# Max leaf nodes: 29205  		 Mean Absolute Error:  29130
# Max leaf nodes: 29255  		 Mean Absolute Error:  29130
# Max leaf nodes: 29305  		 Mean Absolute Error:  29130
# Max leaf nodes: 29355  		 Mean Absolute Error:  29130
# Max leaf nodes: 29405  		 Mean Absolute Error:  29130
# Max leaf nodes: 29455  		 Mean Absolute Error:  29130
# Max leaf nodes: 29505  		 Mean Absolute Error:  29130
# Max leaf nodes: 29555  		 Mean Absolute Error:  29130
# Max leaf nodes: 29605  		 Mean Absolute Error:  29130
# Max leaf nodes: 29655  		 Mean Absolute Error:  29130
# Max leaf nodes: 29705  		 Mean Absolute Error:  29130
# Max leaf nodes: 29755  		 Mean Absolute Error:  29130
# Max leaf nodes: 29805  		 Mean Absolute Error:  29130
# Max leaf nodes: 29855  		 Mean Absolute Error:  29130
# Max leaf nodes: 29905  		 Mean Absolute Error:  29130
# Max leaf nodes: 29955  		 Mean Absolute Error:  29130
# Max leaf nodes: 30005  		 Mean Absolute Error:  29130
# Max leaf nodes: 30055  		 Mean Absolute Error:  29130
# Max leaf nodes: 30105  		 Mean Absolute Error:  29130
# Max leaf nodes: 30155  		 Mean Absolute Error:  29130
# Max leaf nodes: 30205  		 Mean Absolute Error:  29130
# Max leaf nodes: 30255  		 Mean Absolute Error:  29130
# Max leaf nodes: 30305  		 Mean Absolute Error:  29130
# Max leaf nodes: 30355  		 Mean Absolute Error:  29130
# Max leaf nodes: 30405  		 Mean Absolute Error:  29130
# Max leaf nodes: 30455  		 Mean Absolute Error:  29130
# Max leaf nodes: 30505  		 Mean Absolute Error:  29130
# Max leaf nodes: 30555  		 Mean Absolute Error:  29130
# Max leaf nodes: 30605  		 Mean Absolute Error:  29130
# Max leaf nodes: 30655  		 Mean Absolute Error:  29130
# Max leaf nodes: 30705  		 Mean Absolute Error:  29130
# Max leaf nodes: 30755  		 Mean Absolute Error:  29130
# Max leaf nodes: 30805  		 Mean Absolute Error:  29130
# Max leaf nodes: 30855  		 Mean Absolute Error:  29130
# Max leaf nodes: 30905  		 Mean Absolute Error:  29130
# Max leaf nodes: 30955  		 Mean Absolute Error:  29130
# Max leaf nodes: 31005  		 Mean Absolute Error:  29130
# Max leaf nodes: 31055  		 Mean Absolute Error:  29130
# Max leaf nodes: 31105  		 Mean Absolute Error:  29130
# Max leaf nodes: 31155  		 Mean Absolute Error:  29130
# Max leaf nodes: 31205  		 Mean Absolute Error:  29130
# Max leaf nodes: 31255  		 Mean Absolute Error:  29130
# Max leaf nodes: 31305  		 Mean Absolute Error:  29130
# Max leaf nodes: 31355  		 Mean Absolute Error:  29130
# Max leaf nodes: 31405  		 Mean Absolute Error:  29130
# Max leaf nodes: 31455  		 Mean Absolute Error:  29130
# Max leaf nodes: 31505  		 Mean Absolute Error:  29130
# Max leaf nodes: 31555  		 Mean Absolute Error:  29130
# Max leaf nodes: 31605  		 Mean Absolute Error:  29130
# Max leaf nodes: 31655  		 Mean Absolute Error:  29130
# Max leaf nodes: 31705  		 Mean Absolute Error:  29130
# Max leaf nodes: 31755  		 Mean Absolute Error:  29130
# Max leaf nodes: 31805  		 Mean Absolute Error:  29130
# Max leaf nodes: 31855  		 Mean Absolute Error:  29130
# Max leaf nodes: 31905  		 Mean Absolute Error:  29130
# Max leaf nodes: 31955  		 Mean Absolute Error:  29130
# Max leaf nodes: 32005  		 Mean Absolute Error:  29130
# Max leaf nodes: 32055  		 Mean Absolute Error:  29130
# Max leaf nodes: 32105  		 Mean Absolute Error:  29130
# Max leaf nodes: 32155  		 Mean Absolute Error:  29130
# Max leaf nodes: 32205  		 Mean Absolute Error:  29130
# Max leaf nodes: 32255  		 Mean Absolute Error:  29130
# Max leaf nodes: 32305  		 Mean Absolute Error:  29130
# Max leaf nodes: 32355  		 Mean Absolute Error:  29130
# Max leaf nodes: 32405  		 Mean Absolute Error:  29130
# Max leaf nodes: 32455  		 Mean Absolute Error:  29130
# Max leaf nodes: 32505  		 Mean Absolute Error:  29130
# Max leaf nodes: 32555  		 Mean Absolute Error:  29130
# Max leaf nodes: 32605  		 Mean Absolute Error:  29130
# Max leaf nodes: 32655  		 Mean Absolute Error:  29130
# Max leaf nodes: 32705  		 Mean Absolute Error:  29130
# Max leaf nodes: 32755  		 Mean Absolute Error:  29130
# Max leaf nodes: 32805  		 Mean Absolute Error:  29130
# Max leaf nodes: 32855  		 Mean Absolute Error:  29130
# Max leaf nodes: 32905  		 Mean Absolute Error:  29130
# Max leaf nodes: 32955  		 Mean Absolute Error:  29130
# Max leaf nodes: 33005  		 Mean Absolute Error:  29130
# Max leaf nodes: 33055  		 Mean Absolute Error:  29130
# Max leaf nodes: 33105  		 Mean Absolute Error:  29130
# Max leaf nodes: 33155  		 Mean Absolute Error:  29130
# Max leaf nodes: 33205  		 Mean Absolute Error:  29130
# Max leaf nodes: 33255  		 Mean Absolute Error:  29130
# Max leaf nodes: 33305  		 Mean Absolute Error:  29130
# Max leaf nodes: 33355  		 Mean Absolute Error:  29130
# Max leaf nodes: 33405  		 Mean Absolute Error:  29130
# Max leaf nodes: 33455  		 Mean Absolute Error:  29130
# Max leaf nodes: 33505  		 Mean Absolute Error:  29130
# Max leaf nodes: 33555  		 Mean Absolute Error:  29130
# Max leaf nodes: 33605  		 Mean Absolute Error:  29130
# Max leaf nodes: 33655  		 Mean Absolute Error:  29130
# Max leaf nodes: 33705  		 Mean Absolute Error:  29130
# Max leaf nodes: 33755  		 Mean Absolute Error:  29130
# Max leaf nodes: 33805  		 Mean Absolute Error:  29130
# Max leaf nodes: 33855  		 Mean Absolute Error:  29130
# Max leaf nodes: 33905  		 Mean Absolute Error:  29130
# Max leaf nodes: 33955  		 Mean Absolute Error:  29130
# Max leaf nodes: 34005  		 Mean Absolute Error:  29130
# Max leaf nodes: 34055  		 Mean Absolute Error:  29130
# Max leaf nodes: 34105  		 Mean Absolute Error:  29130
# Max leaf nodes: 34155  		 Mean Absolute Error:  29130
# Max leaf nodes: 34205  		 Mean Absolute Error:  29130
# Max leaf nodes: 34255  		 Mean Absolute Error:  29130
# Max leaf nodes: 34305  		 Mean Absolute Error:  29130
# Max leaf nodes: 34355  		 Mean Absolute Error:  29130
# Max leaf nodes: 34405  		 Mean Absolute Error:  29130
# Max leaf nodes: 34455  		 Mean Absolute Error:  29130
# Max leaf nodes: 34505  		 Mean Absolute Error:  29130
# Max leaf nodes: 34555  		 Mean Absolute Error:  29130
# Max leaf nodes: 34605  		 Mean Absolute Error:  29130
# Max leaf nodes: 34655  		 Mean Absolute Error:  29130
# Max leaf nodes: 34705  		 Mean Absolute Error:  29130
# Max leaf nodes: 34755  		 Mean Absolute Error:  29130
# Max leaf nodes: 34805  		 Mean Absolute Error:  29130
# Max leaf nodes: 34855  		 Mean Absolute Error:  29130
# Max leaf nodes: 34905  		 Mean Absolute Error:  29130
# Max leaf nodes: 34955  		 Mean Absolute Error:  29130
# Max leaf nodes: 35005  		 Mean Absolute Error:  29130
# Max leaf nodes: 35055  		 Mean Absolute Error:  29130
# Max leaf nodes: 35105  		 Mean Absolute Error:  29130
# Max leaf nodes: 35155  		 Mean Absolute Error:  29130
# Max leaf nodes: 35205  		 Mean Absolute Error:  29130
# Max leaf nodes: 35255  		 Mean Absolute Error:  29130
# Max leaf nodes: 35305  		 Mean Absolute Error:  29130
# Max leaf nodes: 35355  		 Mean Absolute Error:  29130
# Max leaf nodes: 35405  		 Mean Absolute Error:  29130
# Max leaf nodes: 35455  		 Mean Absolute Error:  29130
# Max leaf nodes: 35505  		 Mean Absolute Error:  29130
# Max leaf nodes: 35555  		 Mean Absolute Error:  29130
# Max leaf nodes: 35605  		 Mean Absolute Error:  29130
# Max leaf nodes: 35655  		 Mean Absolute Error:  29130
# Max leaf nodes: 35705  		 Mean Absolute Error:  29130
# Max leaf nodes: 35755  		 Mean Absolute Error:  29130
# Max leaf nodes: 35805  		 Mean Absolute Error:  29130
# Max leaf nodes: 35855  		 Mean Absolute Error:  29130
# Max leaf nodes: 35905  		 Mean Absolute Error:  29130
# Max leaf nodes: 35955  		 Mean Absolute Error:  29130
# Max leaf nodes: 36005  		 Mean Absolute Error:  29130
# Max leaf nodes: 36055  		 Mean Absolute Error:  29130
# Max leaf nodes: 36105  		 Mean Absolute Error:  29130
# Max leaf nodes: 36155  		 Mean Absolute Error:  29130
# Max leaf nodes: 36205  		 Mean Absolute Error:  29130
# Max leaf nodes: 36255  		 Mean Absolute Error:  29130
# Max leaf nodes: 36305  		 Mean Absolute Error:  29130
# Max leaf nodes: 36355  		 Mean Absolute Error:  29130
# Max leaf nodes: 36405  		 Mean Absolute Error:  29130
# Max leaf nodes: 36455  		 Mean Absolute Error:  29130
# Max leaf nodes: 36505  		 Mean Absolute Error:  29130
# Max leaf nodes: 36555  		 Mean Absolute Error:  29130
# Max leaf nodes: 36605  		 Mean Absolute Error:  29130
# Max leaf nodes: 36655  		 Mean Absolute Error:  29130
# Max leaf nodes: 36705  		 Mean Absolute Error:  29130
# Max leaf nodes: 36755  		 Mean Absolute Error:  29130
# Max leaf nodes: 36805  		 Mean Absolute Error:  29130
# Max leaf nodes: 36855  		 Mean Absolute Error:  29130
# Max leaf nodes: 36905  		 Mean Absolute Error:  29130
# Max leaf nodes: 36955  		 Mean Absolute Error:  29130
# Max leaf nodes: 37005  		 Mean Absolute Error:  29130
# Max leaf nodes: 37055  		 Mean Absolute Error:  29130
# Max leaf nodes: 37105  		 Mean Absolute Error:  29130
# Max leaf nodes: 37155  		 Mean Absolute Error:  29130
# Max leaf nodes: 37205  		 Mean Absolute Error:  29130
# Max leaf nodes: 37255  		 Mean Absolute Error:  29130
# Max leaf nodes: 37305  		 Mean Absolute Error:  29130
# Max leaf nodes: 37355  		 Mean Absolute Error:  29130
# Max leaf nodes: 37405  		 Mean Absolute Error:  29130
# Max leaf nodes: 37455  		 Mean Absolute Error:  29130
# Max leaf nodes: 37505  		 Mean Absolute Error:  29130
# Max leaf nodes: 37555  		 Mean Absolute Error:  29130
# Max leaf nodes: 37605  		 Mean Absolute Error:  29130
# Max leaf nodes: 37655  		 Mean Absolute Error:  29130
# Max leaf nodes: 37705  		 Mean Absolute Error:  29130
# Max leaf nodes: 37755  		 Mean Absolute Error:  29130
# Max leaf nodes: 37805  		 Mean Absolute Error:  29130
# Max leaf nodes: 37855  		 Mean Absolute Error:  29130
# Max leaf nodes: 37905  		 Mean Absolute Error:  29130
# Max leaf nodes: 37955  		 Mean Absolute Error:  29130
# Max leaf nodes: 38005  		 Mean Absolute Error:  29130
# Max leaf nodes: 38055  		 Mean Absolute Error:  29130
# Max leaf nodes: 38105  		 Mean Absolute Error:  29130
# Max leaf nodes: 38155  		 Mean Absolute Error:  29130
# Max leaf nodes: 38205  		 Mean Absolute Error:  29130
# Max leaf nodes: 38255  		 Mean Absolute Error:  29130
# Max leaf nodes: 38305  		 Mean Absolute Error:  29130
# Max leaf nodes: 38355  		 Mean Absolute Error:  29130
# Max leaf nodes: 38405  		 Mean Absolute Error:  29130
# Max leaf nodes: 38455  		 Mean Absolute Error:  29130
# Max leaf nodes: 38505  		 Mean Absolute Error:  29130
# Max leaf nodes: 38555  		 Mean Absolute Error:  29130
# Max leaf nodes: 38605  		 Mean Absolute Error:  29130
# Max leaf nodes: 38655  		 Mean Absolute Error:  29130
# Max leaf nodes: 38705  		 Mean Absolute Error:  29130
# Max leaf nodes: 38755  		 Mean Absolute Error:  29130
# Max leaf nodes: 38805  		 Mean Absolute Error:  29130
# Max leaf nodes: 38855  		 Mean Absolute Error:  29130
# Max leaf nodes: 38905  		 Mean Absolute Error:  29130
# Max leaf nodes: 38955  		 Mean Absolute Error:  29130
# Max leaf nodes: 39005  		 Mean Absolute Error:  29130
# Max leaf nodes: 39055  		 Mean Absolute Error:  29130
# Max leaf nodes: 39105  		 Mean Absolute Error:  29130
# Max leaf nodes: 39155  		 Mean Absolute Error:  29130
# Max leaf nodes: 39205  		 Mean Absolute Error:  29130
# Max leaf nodes: 39255  		 Mean Absolute Error:  29130
# Max leaf nodes: 39305  		 Mean Absolute Error:  29130
# Max leaf nodes: 39355  		 Mean Absolute Error:  29130
# Max leaf nodes: 39405  		 Mean Absolute Error:  29130
# Max leaf nodes: 39455  		 Mean Absolute Error:  29130
# Max leaf nodes: 39505  		 Mean Absolute Error:  29130
# Max leaf nodes: 39555  		 Mean Absolute Error:  29130
# Max leaf nodes: 39605  		 Mean Absolute Error:  29130
# Max leaf nodes: 39655  		 Mean Absolute Error:  29130
# Max leaf nodes: 39705  		 Mean Absolute Error:  29130
# Max leaf nodes: 39755  		 Mean Absolute Error:  29130
# Max leaf nodes: 39805  		 Mean Absolute Error:  29130
# Max leaf nodes: 39855  		 Mean Absolute Error:  29130
# Max leaf nodes: 39905  		 Mean Absolute Error:  29130
# Max leaf nodes: 39955  		 Mean Absolute Error:  29130
# Max leaf nodes: 40005  		 Mean Absolute Error:  29130
# Max leaf nodes: 40055  		 Mean Absolute Error:  29130
# Max leaf nodes: 40105  		 Mean Absolute Error:  29130
# Max leaf nodes: 40155  		 Mean Absolute Error:  29130
# Max leaf nodes: 40205  		 Mean Absolute Error:  29130
# Max leaf nodes: 40255  		 Mean Absolute Error:  29130
# Max leaf nodes: 40305  		 Mean Absolute Error:  29130
# Max leaf nodes: 40355  		 Mean Absolute Error:  29130
# Max leaf nodes: 40405  		 Mean Absolute Error:  29130
# Max leaf nodes: 40455  		 Mean Absolute Error:  29130
# Max leaf nodes: 40505  		 Mean Absolute Error:  29130
# Max leaf nodes: 40555  		 Mean Absolute Error:  29130
# Max leaf nodes: 40605  		 Mean Absolute Error:  29130
# Max leaf nodes: 40655  		 Mean Absolute Error:  29130
# Max leaf nodes: 40705  		 Mean Absolute Error:  29130
# Max leaf nodes: 40755  		 Mean Absolute Error:  29130
# Max leaf nodes: 40805  		 Mean Absolute Error:  29130
# Max leaf nodes: 40855  		 Mean Absolute Error:  29130
# Max leaf nodes: 40905  		 Mean Absolute Error:  29130
# Max leaf nodes: 40955  		 Mean Absolute Error:  29130
# Max leaf nodes: 41005  		 Mean Absolute Error:  29130
# Max leaf nodes: 41055  		 Mean Absolute Error:  29130
# Max leaf nodes: 41105  		 Mean Absolute Error:  29130
# Max leaf nodes: 41155  		 Mean Absolute Error:  29130
# Max leaf nodes: 41205  		 Mean Absolute Error:  29130
# Max leaf nodes: 41255  		 Mean Absolute Error:  29130
# Max leaf nodes: 41305  		 Mean Absolute Error:  29130
# Max leaf nodes: 41355  		 Mean Absolute Error:  29130
# Max leaf nodes: 41405  		 Mean Absolute Error:  29130
# Max leaf nodes: 41455  		 Mean Absolute Error:  29130
# Max leaf nodes: 41505  		 Mean Absolute Error:  29130
# Max leaf nodes: 41555  		 Mean Absolute Error:  29130
# Max leaf nodes: 41605  		 Mean Absolute Error:  29130
# Max leaf nodes: 41655  		 Mean Absolute Error:  29130
# Max leaf nodes: 41705  		 Mean Absolute Error:  29130
# Max leaf nodes: 41755  		 Mean Absolute Error:  29130
# Max leaf nodes: 41805  		 Mean Absolute Error:  29130
# Max leaf nodes: 41855  		 Mean Absolute Error:  29130
# Max leaf nodes: 41905  		 Mean Absolute Error:  29130
# Max leaf nodes: 41955  		 Mean Absolute Error:  29130
# Max leaf nodes: 42005  		 Mean Absolute Error:  29130
# Max leaf nodes: 42055  		 Mean Absolute Error:  29130
# Max leaf nodes: 42105  		 Mean Absolute Error:  29130
# Max leaf nodes: 42155  		 Mean Absolute Error:  29130
# Max leaf nodes: 42205  		 Mean Absolute Error:  29130
# Max leaf nodes: 42255  		 Mean Absolute Error:  29130
# Max leaf nodes: 42305  		 Mean Absolute Error:  29130
# Max leaf nodes: 42355  		 Mean Absolute Error:  29130
# Max leaf nodes: 42405  		 Mean Absolute Error:  29130
# Max leaf nodes: 42455  		 Mean Absolute Error:  29130
# Max leaf nodes: 42505  		 Mean Absolute Error:  29130
# Max leaf nodes: 42555  		 Mean Absolute Error:  29130
# Max leaf nodes: 42605  		 Mean Absolute Error:  29130
# Max leaf nodes: 42655  		 Mean Absolute Error:  29130
# Max leaf nodes: 42705  		 Mean Absolute Error:  29130
# Max leaf nodes: 42755  		 Mean Absolute Error:  29130
# Max leaf nodes: 42805  		 Mean Absolute Error:  29130
# Max leaf nodes: 42855  		 Mean Absolute Error:  29130
# Max leaf nodes: 42905  		 Mean Absolute Error:  29130
# Max leaf nodes: 42955  		 Mean Absolute Error:  29130
# Max leaf nodes: 43005  		 Mean Absolute Error:  29130
# Max leaf nodes: 43055  		 Mean Absolute Error:  29130
# Max leaf nodes: 43105  		 Mean Absolute Error:  29130
# Max leaf nodes: 43155  		 Mean Absolute Error:  29130
# Max leaf nodes: 43205  		 Mean Absolute Error:  29130
# Max leaf nodes: 43255  		 Mean Absolute Error:  29130
# Max leaf nodes: 43305  		 Mean Absolute Error:  29130
# Max leaf nodes: 43355  		 Mean Absolute Error:  29130
# Max leaf nodes: 43405  		 Mean Absolute Error:  29130
# Max leaf nodes: 43455  		 Mean Absolute Error:  29130
# Max leaf nodes: 43505  		 Mean Absolute Error:  29130
# Max leaf nodes: 43555  		 Mean Absolute Error:  29130
# Max leaf nodes: 43605  		 Mean Absolute Error:  29130
# Max leaf nodes: 43655  		 Mean Absolute Error:  29130
# Max leaf nodes: 43705  		 Mean Absolute Error:  29130
# Max leaf nodes: 43755  		 Mean Absolute Error:  29130
# Max leaf nodes: 43805  		 Mean Absolute Error:  29130
# Max leaf nodes: 43855  		 Mean Absolute Error:  29130
# Max leaf nodes: 43905  		 Mean Absolute Error:  29130
# Max leaf nodes: 43955  		 Mean Absolute Error:  29130
# Max leaf nodes: 44005  		 Mean Absolute Error:  29130
# Max leaf nodes: 44055  		 Mean Absolute Error:  29130
# Max leaf nodes: 44105  		 Mean Absolute Error:  29130
# Max leaf nodes: 44155  		 Mean Absolute Error:  29130
# Max leaf nodes: 44205  		 Mean Absolute Error:  29130
# Max leaf nodes: 44255  		 Mean Absolute Error:  29130
# Max leaf nodes: 44305  		 Mean Absolute Error:  29130
# Max leaf nodes: 44355  		 Mean Absolute Error:  29130
# Max leaf nodes: 44405  		 Mean Absolute Error:  29130
# Max leaf nodes: 44455  		 Mean Absolute Error:  29130
# Max leaf nodes: 44505  		 Mean Absolute Error:  29130
# Max leaf nodes: 44555  		 Mean Absolute Error:  29130
# Max leaf nodes: 44605  		 Mean Absolute Error:  29130
# ...
# Max leaf nodes: 85205  		 Mean Absolute Error:  29130
# Max leaf nodes: 85255  		 Mean Absolute Error:  29130
# Max leaf nodes: 85305  		 Mean Absolute Error:  29130
# Max leaf nodes: 85355  		 Mean Absolute Error:  29130
# Max leaf nodes: 85405  		 Mean Absolute Error:  29130
# Max leaf nodes: 85455  		 Mean Absolute Error:  29130
# Max leaf nodes: 85505  		 Mean Absolute Error:  29130
# Max leaf nodes: 85555  		 Mean Absolute Error:  29130
# Max leaf nodes: 85605  		 Mean Absolute Error:  29130
# Max leaf nodes: 85655  		 Mean Absolute Error:  29130
# Max leaf nodes: 85705  		 Mean Absolute Error:  29130
# Max leaf nodes: 85755  		 Mean Absolute Error:  29130
# Max leaf nodes: 85805  		 Mean Absolute Error:  29130
# Max leaf nodes: 85855  		 Mean Absolute Error:  29130
# Max leaf nodes: 85905  		 Mean Absolute Error:  29130
# Max leaf nodes: 85955  		 Mean Absolute Error:  29130
# Max leaf nodes: 86005  		 Mean Absolute Error:  29130
# Max leaf nodes: 86055  		 Mean Absolute Error:  29130
# Max leaf nodes: 86105  		 Mean Absolute Error:  29130
# Max leaf nodes: 86155  		 Mean Absolute Error:  29130
# Max leaf nodes: 86205  		 Mean Absolute Error:  29130
# Max leaf nodes: 86255  		 Mean Absolute Error:  29130
# Max leaf nodes: 86305  		 Mean Absolute Error:  29130
# Max leaf nodes: 86355  		 Mean Absolute Error:  29130
# Max leaf nodes: 86405  		 Mean Absolute Error:  29130
# Max leaf nodes: 86455  		 Mean Absolute Error:  29130
# Max leaf nodes: 86505  		 Mean Absolute Error:  29130
# Max leaf nodes: 86555  		 Mean Absolute Error:  29130
# Max leaf nodes: 86605  		 Mean Absolute Error:  29130
# Max leaf nodes: 86655  		 Mean Absolute Error:  29130
# Max leaf nodes: 86705  		 Mean Absolute Error:  29130
# Max leaf nodes: 86755  		 Mean Absolute Error:  29130
# Max leaf nodes: 86805  		 Mean Absolute Error:  29130
# Max leaf nodes: 86855  		 Mean Absolute Error:  29130
# Max leaf nodes: 86905  		 Mean Absolute Error:  29130
# Max leaf nodes: 86955  		 Mean Absolute Error:  29130
# Max leaf nodes: 87005  		 Mean Absolute Error:  29130
# Max leaf nodes: 87055  		 Mean Absolute Error:  29130
# Max leaf nodes: 87105  		 Mean Absolute Error:  29130
# Max leaf nodes: 87155  		 Mean Absolute Error:  29130
# Max leaf nodes: 87205  		 Mean Absolute Error:  29130
# Max leaf nodes: 87255  		 Mean Absolute Error:  29130
# Max leaf nodes: 87305  		 Mean Absolute Error:  29130
# Max leaf nodes: 87355  		 Mean Absolute Error:  29130
# Max leaf nodes: 87405  		 Mean Absolute Error:  29130
# Max leaf nodes: 87455  		 Mean Absolute Error:  29130
# Max leaf nodes: 87505  		 Mean Absolute Error:  29130
# Max leaf nodes: 87555  		 Mean Absolute Error:  29130
# Max leaf nodes: 87605  		 Mean Absolute Error:  29130
# Max leaf nodes: 87655  		 Mean Absolute Error:  29130
# Max leaf nodes: 87705  		 Mean Absolute Error:  29130
# Max leaf nodes: 87755  		 Mean Absolute Error:  29130
# Max leaf nodes: 87805  		 Mean Absolute Error:  29130
# Max leaf nodes: 87855  		 Mean Absolute Error:  29130
# Max leaf nodes: 87905  		 Mean Absolute Error:  29130
# Max leaf nodes: 87955  		 Mean Absolute Error:  29130
# Max leaf nodes: 88005  		 Mean Absolute Error:  29130
# Max leaf nodes: 88055  		 Mean Absolute Error:  29130
# Max leaf nodes: 88105  		 Mean Absolute Error:  29130
# Max leaf nodes: 88155  		 Mean Absolute Error:  29130
# Max leaf nodes: 88205  		 Mean Absolute Error:  29130
# Max leaf nodes: 88255  		 Mean Absolute Error:  29130
# Max leaf nodes: 88305  		 Mean Absolute Error:  29130
# Max leaf nodes: 88355  		 Mean Absolute Error:  29130
# Max leaf nodes: 88405  		 Mean Absolute Error:  29130
# Max leaf nodes: 88455  		 Mean Absolute Error:  29130
# Max leaf nodes: 88505  		 Mean Absolute Error:  29130
# Max leaf nodes: 88555  		 Mean Absolute Error:  29130
# Max leaf nodes: 88605  		 Mean Absolute Error:  29130
# Max leaf nodes: 88655  		 Mean Absolute Error:  29130
# Max leaf nodes: 88705  		 Mean Absolute Error:  29130
# Max leaf nodes: 88755  		 Mean Absolute Error:  29130
# Max leaf nodes: 88805  		 Mean Absolute Error:  29130
# Max leaf nodes: 88855  		 Mean Absolute Error:  29130
# Max leaf nodes: 88905  		 Mean Absolute Error:  29130
# Max leaf nodes: 88955  		 Mean Absolute Error:  29130
# Max leaf nodes: 89005  		 Mean Absolute Error:  29130
# Max leaf nodes: 89055  		 Mean Absolute Error:  29130
# Max leaf nodes: 89105  		 Mean Absolute Error:  29130
# Max leaf nodes: 89155  		 Mean Absolute Error:  29130
# Max leaf nodes: 89205  		 Mean Absolute Error:  29130
# Max leaf nodes: 89255  		 Mean Absolute Error:  29130
# Max leaf nodes: 89305  		 Mean Absolute Error:  29130
# Max leaf nodes: 89355  		 Mean Absolute Error:  29130
# Max leaf nodes: 89405  		 Mean Absolute Error:  29130
# Max leaf nodes: 89455  		 Mean Absolute Error:  29130
# Max leaf nodes: 89505  		 Mean Absolute Error:  29130
# Max leaf nodes: 89555  		 Mean Absolute Error:  29130
# Max leaf nodes: 89605  		 Mean Absolute Error:  29130
# Max leaf nodes: 89655  		 Mean Absolute Error:  29130
# Max leaf nodes: 89705  		 Mean Absolute Error:  29130
# Max leaf nodes: 89755  		 Mean Absolute Error:  29130
# Max leaf nodes: 89805  		 Mean Absolute Error:  29130
# Max leaf nodes: 89855  		 Mean Absolute Error:  29130
# Max leaf nodes: 89905  		 Mean Absolute Error:  29130
# Max leaf nodes: 89955  		 Mean Absolute Error:  29130
# Max leaf nodes: 90005  		 Mean Absolute Error:  29130
# Max leaf nodes: 90055  		 Mean Absolute Error:  29130
# Max leaf nodes: 90105  		 Mean Absolute Error:  29130
# Max leaf nodes: 90155  		 Mean Absolute Error:  29130
# Max leaf nodes: 90205  		 Mean Absolute Error:  29130
# Max leaf nodes: 90255  		 Mean Absolute Error:  29130
# Max leaf nodes: 90305  		 Mean Absolute Error:  29130
# Max leaf nodes: 90355  		 Mean Absolute Error:  29130
# Max leaf nodes: 90405  		 Mean Absolute Error:  29130
# Max leaf nodes: 90455  		 Mean Absolute Error:  29130
# Max leaf nodes: 90505  		 Mean Absolute Error:  29130
# Max leaf nodes: 90555  		 Mean Absolute Error:  29130
# Max leaf nodes: 90605  		 Mean Absolute Error:  29130
# Max leaf nodes: 90655  		 Mean Absolute Error:  29130
# Max leaf nodes: 90705  		 Mean Absolute Error:  29130
# Max leaf nodes: 90755  		 Mean Absolute Error:  29130
# Max leaf nodes: 90805  		 Mean Absolute Error:  29130
# Max leaf nodes: 90855  		 Mean Absolute Error:  29130
# Max leaf nodes: 90905  		 Mean Absolute Error:  29130
# Max leaf nodes: 90955  		 Mean Absolute Error:  29130
# Max leaf nodes: 91005  		 Mean Absolute Error:  29130
# Max leaf nodes: 91055  		 Mean Absolute Error:  29130
# Max leaf nodes: 91105  		 Mean Absolute Error:  29130
# Max leaf nodes: 91155  		 Mean Absolute Error:  29130
# Max leaf nodes: 91205  		 Mean Absolute Error:  29130
# Max leaf nodes: 91255  		 Mean Absolute Error:  29130
# Max leaf nodes: 91305  		 Mean Absolute Error:  29130
# Max leaf nodes: 91355  		 Mean Absolute Error:  29130
# Max leaf nodes: 91405  		 Mean Absolute Error:  29130
# Max leaf nodes: 91455  		 Mean Absolute Error:  29130
# Max leaf nodes: 91505  		 Mean Absolute Error:  29130
# Max leaf nodes: 91555  		 Mean Absolute Error:  29130
# Max leaf nodes: 91605  		 Mean Absolute Error:  29130
# Max leaf nodes: 91655  		 Mean Absolute Error:  29130
# Max leaf nodes: 91705  		 Mean Absolute Error:  29130
# Max leaf nodes: 91755  		 Mean Absolute Error:  29130
# Max leaf nodes: 91805  		 Mean Absolute Error:  29130
# Max leaf nodes: 91855  		 Mean Absolute Error:  29130
# Max leaf nodes: 91905  		 Mean Absolute Error:  29130
# Max leaf nodes: 91955  		 Mean Absolute Error:  29130
# Max leaf nodes: 92005  		 Mean Absolute Error:  29130
# Max leaf nodes: 92055  		 Mean Absolute Error:  29130
# Max leaf nodes: 92105  		 Mean Absolute Error:  29130
# Max leaf nodes: 92155  		 Mean Absolute Error:  29130
# Max leaf nodes: 92205  		 Mean Absolute Error:  29130
# Max leaf nodes: 92255  		 Mean Absolute Error:  29130
# Max leaf nodes: 92305  		 Mean Absolute Error:  29130
# Max leaf nodes: 92355  		 Mean Absolute Error:  29130
# Max leaf nodes: 92405  		 Mean Absolute Error:  29130
# Max leaf nodes: 92455  		 Mean Absolute Error:  29130
# Max leaf nodes: 92505  		 Mean Absolute Error:  29130
# Max leaf nodes: 92555  		 Mean Absolute Error:  29130
# Max leaf nodes: 92605  		 Mean Absolute Error:  29130
# Max leaf nodes: 92655  		 Mean Absolute Error:  29130
# Max leaf nodes: 92705  		 Mean Absolute Error:  29130
# Max leaf nodes: 92755  		 Mean Absolute Error:  29130
# Max leaf nodes: 92805  		 Mean Absolute Error:  29130
# Max leaf nodes: 92855  		 Mean Absolute Error:  29130
# Max leaf nodes: 92905  		 Mean Absolute Error:  29130
# Max leaf nodes: 92955  		 Mean Absolute Error:  29130
# Max leaf nodes: 93005  		 Mean Absolute Error:  29130
# Max leaf nodes: 93055  		 Mean Absolute Error:  29130
# Max leaf nodes: 93105  		 Mean Absolute Error:  29130
# Max leaf nodes: 93155  		 Mean Absolute Error:  29130
# Max leaf nodes: 93205  		 Mean Absolute Error:  29130
# Max leaf nodes: 93255  		 Mean Absolute Error:  29130
# Max leaf nodes: 93305  		 Mean Absolute Error:  29130
# Max leaf nodes: 93355  		 Mean Absolute Error:  29130
# Max leaf nodes: 93405  		 Mean Absolute Error:  29130
# Max leaf nodes: 93455  		 Mean Absolute Error:  29130
# Max leaf nodes: 93505  		 Mean Absolute Error:  29130
# Max leaf nodes: 93555  		 Mean Absolute Error:  29130
# Max leaf nodes: 93605  		 Mean Absolute Error:  29130
# Max leaf nodes: 93655  		 Mean Absolute Error:  29130
# Max leaf nodes: 93705  		 Mean Absolute Error:  29130
# Max leaf nodes: 93755  		 Mean Absolute Error:  29130
# Max leaf nodes: 93805  		 Mean Absolute Error:  29130
# Max leaf nodes: 93855  		 Mean Absolute Error:  29130
# Max leaf nodes: 93905  		 Mean Absolute Error:  29130
# Max leaf nodes: 93955  		 Mean Absolute Error:  29130
# Max leaf nodes: 94005  		 Mean Absolute Error:  29130
# Max leaf nodes: 94055  		 Mean Absolute Error:  29130
# Max leaf nodes: 94105  		 Mean Absolute Error:  29130
# Max leaf nodes: 94155  		 Mean Absolute Error:  29130
# Max leaf nodes: 94205  		 Mean Absolute Error:  29130
# Max leaf nodes: 94255  		 Mean Absolute Error:  29130
# Max leaf nodes: 94305  		 Mean Absolute Error:  29130
# Max leaf nodes: 94355  		 Mean Absolute Error:  29130
# Max leaf nodes: 94405  		 Mean Absolute Error:  29130
# Max leaf nodes: 94455  		 Mean Absolute Error:  29130
# Max leaf nodes: 94505  		 Mean Absolute Error:  29130
# Max leaf nodes: 94555  		 Mean Absolute Error:  29130
# Max leaf nodes: 94605  		 Mean Absolute Error:  29130
# Max leaf nodes: 94655  		 Mean Absolute Error:  29130
# Max leaf nodes: 94705  		 Mean Absolute Error:  29130
# Max leaf nodes: 94755  		 Mean Absolute Error:  29130
# Max leaf nodes: 94805  		 Mean Absolute Error:  29130
# Max leaf nodes: 94855  		 Mean Absolute Error:  29130
# Max leaf nodes: 94905  		 Mean Absolute Error:  29130
# Max leaf nodes: 94955  		 Mean Absolute Error:  29130
# Max leaf nodes: 95005  		 Mean Absolute Error:  29130
# Max leaf nodes: 95055  		 Mean Absolute Error:  29130
# Max leaf nodes: 95105  		 Mean Absolute Error:  29130
# Max leaf nodes: 95155  		 Mean Absolute Error:  29130
# Max leaf nodes: 95205  		 Mean Absolute Error:  29130
# Max leaf nodes: 95255  		 Mean Absolute Error:  29130
# Max leaf nodes: 95305  		 Mean Absolute Error:  29130
# Max leaf nodes: 95355  		 Mean Absolute Error:  29130
# Max leaf nodes: 95405  		 Mean Absolute Error:  29130
# Max leaf nodes: 95455  		 Mean Absolute Error:  29130
# Max leaf nodes: 95505  		 Mean Absolute Error:  29130
# Max leaf nodes: 95555  		 Mean Absolute Error:  29130
# Max leaf nodes: 95605  		 Mean Absolute Error:  29130
# Max leaf nodes: 95655  		 Mean Absolute Error:  29130
# Max leaf nodes: 95705  		 Mean Absolute Error:  29130
# Max leaf nodes: 95755  		 Mean Absolute Error:  29130
# Max leaf nodes: 95805  		 Mean Absolute Error:  29130
# Max leaf nodes: 95855  		 Mean Absolute Error:  29130
# Max leaf nodes: 95905  		 Mean Absolute Error:  29130
# Max leaf nodes: 95955  		 Mean Absolute Error:  29130
# Max leaf nodes: 96005  		 Mean Absolute Error:  29130
# Max leaf nodes: 96055  		 Mean Absolute Error:  29130
# Max leaf nodes: 96105  		 Mean Absolute Error:  29130
# Max leaf nodes: 96155  		 Mean Absolute Error:  29130
# Max leaf nodes: 96205  		 Mean Absolute Error:  29130
# Max leaf nodes: 96255  		 Mean Absolute Error:  29130
# Max leaf nodes: 96305  		 Mean Absolute Error:  29130
# Max leaf nodes: 96355  		 Mean Absolute Error:  29130
# Max leaf nodes: 96405  		 Mean Absolute Error:  29130
# Max leaf nodes: 96455  		 Mean Absolute Error:  29130
# Max leaf nodes: 96505  		 Mean Absolute Error:  29130
# Max leaf nodes: 96555  		 Mean Absolute Error:  29130
# Max leaf nodes: 96605  		 Mean Absolute Error:  29130
# Max leaf nodes: 96655  		 Mean Absolute Error:  29130
# Max leaf nodes: 96705  		 Mean Absolute Error:  29130
# Max leaf nodes: 96755  		 Mean Absolute Error:  29130
# Max leaf nodes: 96805  		 Mean Absolute Error:  29130
# Max leaf nodes: 96855  		 Mean Absolute Error:  29130
# Max leaf nodes: 96905  		 Mean Absolute Error:  29130
# Max leaf nodes: 96955  		 Mean Absolute Error:  29130
# Max leaf nodes: 97005  		 Mean Absolute Error:  29130
# Max leaf nodes: 97055  		 Mean Absolute Error:  29130
# Max leaf nodes: 97105  		 Mean Absolute Error:  29130
# Max leaf nodes: 97155  		 Mean Absolute Error:  29130
# Max leaf nodes: 97205  		 Mean Absolute Error:  29130
# Max leaf nodes: 97255  		 Mean Absolute Error:  29130
# Max leaf nodes: 97305  		 Mean Absolute Error:  29130
# Max leaf nodes: 97355  		 Mean Absolute Error:  29130
# Max leaf nodes: 97405  		 Mean Absolute Error:  29130
# Max leaf nodes: 97455  		 Mean Absolute Error:  29130
# Max leaf nodes: 97505  		 Mean Absolute Error:  29130
# Max leaf nodes: 97555  		 Mean Absolute Error:  29130
# Max leaf nodes: 97605  		 Mean Absolute Error:  29130
# Max leaf nodes: 97655  		 Mean Absolute Error:  29130
# Max leaf nodes: 97705  		 Mean Absolute Error:  29130
# Max leaf nodes: 97755  		 Mean Absolute Error:  29130
# Max leaf nodes: 97805  		 Mean Absolute Error:  29130
# Max leaf nodes: 97855  		 Mean Absolute Error:  29130
# Max leaf nodes: 97905  		 Mean Absolute Error:  29130
# Max leaf nodes: 97955  		 Mean Absolute Error:  29130
# Max leaf nodes: 98005  		 Mean Absolute Error:  29130
# Max leaf nodes: 98055  		 Mean Absolute Error:  29130
# Max leaf nodes: 98105  		 Mean Absolute Error:  29130
# Max leaf nodes: 98155  		 Mean Absolute Error:  29130
# Max leaf nodes: 98205  		 Mean Absolute Error:  29130
# Max leaf nodes: 98255  		 Mean Absolute Error:  29130
# Max leaf nodes: 98305  		 Mean Absolute Error:  29130
# Max leaf nodes: 98355  		 Mean Absolute Error:  29130
# Max leaf nodes: 98405  		 Mean Absolute Error:  29130
# Max leaf nodes: 98455  		 Mean Absolute Error:  29130
# Max leaf nodes: 98505  		 Mean Absolute Error:  29130
# Max leaf nodes: 98555  		 Mean Absolute Error:  29130
# Max leaf nodes: 98605  		 Mean Absolute Error:  29130
# Max leaf nodes: 98655  		 Mean Absolute Error:  29130
# Max leaf nodes: 98705  		 Mean Absolute Error:  29130
# Max leaf nodes: 98755  		 Mean Absolute Error:  29130
# Max leaf nodes: 98805  		 Mean Absolute Error:  29130
# Max leaf nodes: 98855  		 Mean Absolute Error:  29130
# Max leaf nodes: 98905  		 Mean Absolute Error:  29130
# Max leaf nodes: 98955  		 Mean Absolute Error:  29130
# Max leaf nodes: 99005  		 Mean Absolute Error:  29130
# Max leaf nodes: 99055  		 Mean Absolute Error:  29130
# Max leaf nodes: 99105  		 Mean Absolute Error:  29130
# Max leaf nodes: 99155  		 Mean Absolute Error:  29130
# Max leaf nodes: 99205  		 Mean Absolute Error:  29130
# Max leaf nodes: 99255  		 Mean Absolute Error:  29130
# Max leaf nodes: 99305  		 Mean Absolute Error:  29130
# Max leaf nodes: 99355  		 Mean Absolute Error:  29130
# Max leaf nodes: 99405  		 Mean Absolute Error:  29130
# Max leaf nodes: 99455  		 Mean Absolute Error:  29130
# Max leaf nodes: 99505  		 Mean Absolute Error:  29130
# Max leaf nodes: 99555  		 Mean Absolute Error:  29130
# Max leaf nodes: 99605  		 Mean Absolute Error:  29130
# Max leaf nodes: 99655  		 Mean Absolute Error:  29130
# Max leaf nodes: 99705  		 Mean Absolute Error:  29130
# Max leaf nodes: 99755  		 Mean Absolute Error:  29130
# Max leaf nodes: 99805  		 Mean Absolute Error:  29130
# Max leaf nodes: 99855  		 Mean Absolute Error:  29130
# Max leaf nodes: 99905  		 Mean Absolute Error:  29130
# Max leaf nodes: 99955  		 Mean Absolute Error:  29130

# %%
sorted_scores = sorted(scores, key=lambda score: score[1])

# %%
print("Best: max_leaf_nodes = %d, MAE = %d" %sorted_scores[0])
# Out:
# Best: max_leaf_nodes = 55, MAE = 25041
